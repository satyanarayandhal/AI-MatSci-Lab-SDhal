# %%
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import torch
import matminer

print("Environment Setup Successful!")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"PyTorch version: {torch.__version__}")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Anaconda\envs\aimatsci\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Anaconda\envs\aimatsci\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Anaconda\envs\aimatsci\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Anaconda\envs\aimatsci\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Anaconda\envs\aimatsci\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Dr Satyanarayan Dhal\AppData\Local\Temp\ipykernel_19920\4244731750.py", line 5, in <module>
#     import torch
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\torch\__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\torch\functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\torch\nn\__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\torch\nn\modules\__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "C:\Anaconda\envs\aimatsci\lib\site-packages\torch\nn\modules\transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# C:\Anaconda\envs\aimatsci\lib\site-packages\torch\nn\modules\transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# Environment Setup Successful!
# NumPy version: 2.2.5
# Pandas version: 2.3.3
# PyTorch version: 2.2.2
